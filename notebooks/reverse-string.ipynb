// %% [markdown]
// ## Problem Statement
// Write a function that reverses a string. The function should take a string as input and return a new string with characters in reverse order.
//
// ### Inputs
// s: a string to reverse
// ### Output
// The reversed string
//
// ### Examples
// - "hello" → "olleh"
// - "AlgoMonster" → "retsnomoglA"
// - "a" → "a"

// %%
fun reverseString(s : String) : String {
    return s.reversed()
}
println(reverseString("hello"))
// Out:
// olleh

// %% [markdown]
// ## Developer Approach
// - Use function from Kotlin standard library to reverse the string.
